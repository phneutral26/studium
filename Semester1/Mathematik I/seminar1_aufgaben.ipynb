# %%
import numpy as np
from matplotlib import pyplot as pp

# %%
x = np.arange(-10,10)

x

x[x<=4]

x[abs (x-2)<5]
# Out:
# array([-2, -1,  0,  1,  2,  3,  4,  5,  6])

# %%
pp.grid()
pp.plot(abs(x-2), '.')
pp.axhline(5)
pp.plot(x, (x+4)*(x-3), '.', label='(x+4) (x-3)')
pp.plot(x, x+8, '.', label='x+8')
pp.legend()
